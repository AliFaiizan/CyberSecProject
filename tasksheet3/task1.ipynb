# %%
    
from glob import glob
from utils import load_data


train_files = sorted(glob("../datasets/hai-22.04/train1.csv"))
test_files  = sorted(glob("../datasets/hai-22.04/test1.csv"))

X, y = load_data(train_files, test_files)   # X = readings, y = attack labels
print(f"[INFO] Loaded dataset: {X.shape}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 import glob
#       2 from utils import load_data
# ----> 5 train_files = sorted(glob("../datasets/hai-22.04/train1.csv"))
#       6 test_files  = sorted(glob("../datasets/hai-22.04/test1.csv"))
#       8 X, y = load_data(train_files, test_files)   # X = readings, y = attack labels
#
# TypeError: 'module' object is not callable. Did you mean: 'glob.glob(...)'?
